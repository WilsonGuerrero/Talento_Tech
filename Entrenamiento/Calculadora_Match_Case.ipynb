# %%
#Importando la libreria/biblioteca de matemáticas de Python:
import math

#DEFINICION DE LAS FUNCIONES:
def mostrar_titulo():
    print('Ejemplo Calculadora Sencilla con funciones:')


def mostrar_menu():
    print()
    print("MENU:")
    print("0: Salir")
    print("1: Sumar (+)")
    print("2: Restar (-)")
    print("3: Multiplicar (*)")
    print("4: Dividir (/)")
    print("5: Potenciacion (**)")
    print("6: Radicacion (rad)")
    print("7: Logaritmo (log10)")
    print("8: Seno (sen)")
    print("9: Coseno (cos)")
    print("10: Tangente (tan)")
    print()

def ingresar_datos():
    opcion = input("Ingrese la opción deseada del menú: ") # la opción se guarda como cadena
    if opcion == '0':
        return opcion, 0, 0
    else:
        numero_uno = float(input('Ingrese el primer número de la operación:')) # guarda como flotante (número real)
        numero_dos = float(input('Ingrese el segundo número de la operación:')) # guarda como flotante (número real)
        return opcion, numero_uno, numero_dos


def calcular_suma(numero_uno, numero_dos):
    return numero_uno + numero_dos

def calcular_resta(numero_uno, numero_dos):
    return numero_uno - numero_dos

def calcular_multiplicacion(numero_uno, numero_dos):
    return numero_uno * numero_dos

def calcular_division(numero_uno, numero_dos):
    return numero_uno / numero_dos

def calcular_potencia(numero_uno, numero_dos):
    return numero_uno ** numero_dos

def calcular_raiz(numero_uno, numero_dos):
    return numero_uno ** (1 / numero_dos)

def calcular_logaritmo_base10(numero): # x=numero (uno,dos)
    # aquí uso la función logaritmo que está dentro de math
    return math.log10(numero) # x=numero

def calcular_seno(angulo_grados):
    angulo_radianes = math.radians(angulo_grados)
    seno = math.sin(angulo_radianes)
    return round(seno, 10)

def calcular_coseno(angulo_grados):
    angulo_radianes = math.radians(angulo_grados)
    coseno = math.cos(angulo_radianes)
    return round(coseno, 10)

def calcular_tangente(angulo_grados):
    angulo_radianes = math.radians(angulo_grados)
    tangente = math.tan(angulo_radianes)
    return round(tangente, 10)

def procesar_y_mostrar_operacion(opcion, numero_uno, numero_dos):
    match opcion:
        case '1' | '+' | 'Sumar':
            print("Vamos a sumar(+) los dos valores ingresados:")
            resultado = calcular_suma(numero_uno, numero_dos)
            print('La suma es:', resultado)

        case '2' | '-' | 'Restar':
            print("Vamos a restar(-) los dos valores ingresados:\n")
            resultado = calcular_resta(numero_uno, numero_dos)
            print("Resultado=", resultado)

        case '3' | '*' | 'Multiplicar':
            print("Vamos a multiplicar(*) los dos valores ingresados:\n")
            resultado = calcular_multiplicacion(numero_uno, numero_dos)
            print("Resultado=", resultado)

        case '4' | '/' | 'Dividir':
            print("Vamos a dividir(/) los dos valores ingresados:\n")
            # VALIDANDO EL DENOMINADOR (debe ser diferente de cero)
            if numero_dos != 0:
                resultado = calcular_division(numero_uno, numero_dos)
                print("Resultado=", resultado)
            else:
                print("¡No es posible dividir entre cero!")

        case '5' | '**' | 'Potencia':
            print("Vamos a calcular la potencia (**) de los dos valores ingresados:\n")
            resultado = calcular_potencia(numero_uno, numero_dos)
            print("Resultado=", resultado)

        case '6' | 'rad' | 'Raiz':
            if numero_uno < 0:
                print("¡No es posible calcular la raiz de un número negativo!")
            else:
                print("Vamos a calcular la raiz (rad) de los dos valores ingresados:\n")
                resultado = calcular_raiz(numero_uno, numero_dos)
                print("Resultado=", resultado)

        case '7' | 'log10' | 'Logaritmo':
            print("Vamos a calcular el logaritmo (log10) de los dos valores ingresados:\n")
            resultado1 = calcular_logaritmo_base10(numero_uno)
            resultado2 = calcular_logaritmo_base10(numero_dos)
            print("Resultado1=", resultado1)
            print("Resultado2=", resultado2)

        case '8' | 'sen' | 'Seno':
            print("Vamos a calcular el seno (sen) de los dos valores ingresados:\n")
            resultado1 = calcular_seno(numero_uno)
            print("Resultado1=", resultado1)
            resultado2 = calcular_seno(numero_dos)
            print("Resultado2=", resultado2)

        case '9' | 'cos' | 'Coseno':
            print("Vamos a calcular el coseno (cos) de los dos valores ingresados:\n")
            resultado1 = calcular_coseno(numero_uno)
            resultado2 = calcular_coseno(numero_dos)
            print("Resultado1=", resultado1)
            print("Resultado2=", resultado2)

        case '10' | 'tan' | 'Tangente':
            print("Vamos a calcular la tangente (tan) de los dos valores ingresados:\n")
            resultado1 = calcular_tangente(numero_uno)
            resultado2 = calcular_tangente(numero_dos)
            print("Resultado1=", resultado1)
            print("Resultado2=", resultado2)

        case _:
            print("Opción no válida. Por favor, seleccione una opción del menú.")

def llamar_funciones():
    while True:
        mostrar_titulo()
        mostrar_menu()
        opcion, numero_uno, numero_dos = ingresar_datos()

        if opcion == '0':
            print("Gracias por usar el programa!")
            break

        procesar_y_mostrar_operacion(opcion, numero_uno, numero_dos)
        input("Presione enter para continuar...")


#EJECUCION DEL PROGRAMA:
llamar_funciones()
# Out:
# Ejemplo Calculadora Sencilla con funciones:
#
# MENU:
# 0: Salir
# 1: Sumar (+)
# 2: Restar (-)
# 3: Multiplicar (*)
# 4: Dividir (/)
# 5: Potenciacion (**)
# 6: Radicacion (rad)
# 7: Logaritmo (log10)
# 8: Seno (sen)
# 9: Coseno (cos)
# 10: Tangente (tan)
#
# Ingrese la opción deseada del menú: 1
# Ingrese el primer número de la operación:88
# Ingrese el segundo número de la operación:23
# Vamos a sumar(+) los dos valores ingresados:
# La suma es: 111.0
# Presione enter para continuar...
# Ejemplo Calculadora Sencilla con funciones:
#
# MENU:
# 0: Salir
# 1: Sumar (+)
# 2: Restar (-)
# 3: Multiplicar (*)
# 4: Dividir (/)
# 5: Potenciacion (**)
# 6: Radicacion (rad)
# 7: Logaritmo (log10)
# 8: Seno (sen)
# 9: Coseno (cos)
# 10: Tangente (tan)
#
# Ingrese la opción deseada del menú: 2
# Ingrese el primer número de la operación:8
# Ingrese el segundo número de la operación:15
# Vamos a restar(-) los dos valores ingresados:
#
# Resultado= -7.0
# Presione enter para continuar...
# Ejemplo Calculadora Sencilla con funciones:
#
# MENU:
# 0: Salir
# 1: Sumar (+)
# 2: Restar (-)
# 3: Multiplicar (*)
# 4: Dividir (/)
# 5: Potenciacion (**)
# 6: Radicacion (rad)
# 7: Logaritmo (log10)
# 8: Seno (sen)
# 9: Coseno (cos)
# 10: Tangente (tan)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3595150790.py in <cell line: 0>()
#     155
#     156 #EJECUCION DEL PROGRAMA:
# --> 157 llamar_funciones()
#
# /tmp/ipython-input-3595150790.py in llamar_funciones()
#     144         mostrar_titulo()
#     145         mostrar_menu()
# --> 146         opcion, numero_uno, numero_dos = ingresar_datos()
#     147
#     148         if opcion == '0':
#
# /tmp/ipython-input-3595150790.py in ingresar_datos()
#      24
#      25 def ingresar_datos():
# ---> 26     opcion = input("Ingrese la opción deseada del menú: ") # la opción se guarda como cadena
#      27     if opcion == '0':
#      28         return opcion, 0, 0
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

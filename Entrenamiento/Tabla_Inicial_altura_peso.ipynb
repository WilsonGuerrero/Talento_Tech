# %%
import pandas as pd
lista_nombres = ["Alexander", "Alejandra", "Dario", "Wilson", "Rosa"]
lista_pesos = [69, 57, 64, 80, 40] #peso en Kg
lista_alturas = [1.78, 1.6, 4.64, 1.71, 1.53] #altura en metros
#Convierto el diccionario en un Dataframe (marco de datos = tabla = conjunto de datos)
dicc_datos = {"Nombre": lista_nombres, "Peso": lista_pesos, "Altura": lista_alturas}
df = pd.DataFrame(dicc_datos)
print(df)
# Out:
#       Nombre  Peso  Altura
# 0  Alexander    69    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    4.64
# 3     Wilson    80    1.71
# 4       Rosa    40    1.53

# %%
import pandas as pd
lista_nombres = ["Alexander", "Alejandra", "Dario", "Wilson", "Rosa", "Carlos", "María", "Juan", "Laura", "Pedro", "Ana",
                 "Luis", "Sofía", "Miguel", "Elena", "Diego", "Carmen", "Javier", "Isabel", "Ricardo"]
lista_pesos = [69, 57, 64, 80, 40, 75, 62, 85, 58, 90, 55, 78, 60, 82, 65, 70, 53, 88, 59, 77] #peso en Kg
lista_alturas = [1.78, 1.6, 4.64, 1.71, 1.53, 1.82, 1.65, 1.75, 1.63, 1.78, 1.60, 1.70, 1.62, 1.80, 1.67, 1.74, 1.58, 1.79, 1.61, 1.73] #altura en metros
#Convierto el diccionario en un Dataframe (marco de datos = tabla = conjunto de datos)
dicc_datos = {"Nombre": lista_nombres, "Peso": lista_pesos, "Altura": lista_alturas}
df = pd.DataFrame(dicc_datos)
print(df)
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    4.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5      Carlos    75    1.82
# 6       María    62    1.65
# 7        Juan    85    1.75
# 8       Laura    58    1.63
# 9       Pedro    90    1.78
# 10        Ana    55    1.60
# 11       Luis    78    1.70
# 12      Sofía    60    1.62
# 13     Miguel    82    1.80
# 14      Elena    65    1.67
# 15      Diego    70    1.74
# 16     Carmen    53    1.58
# 17     Javier    88    1.79
# 18     Isabel    59    1.61
# 19    Ricardo    77    1.73

# %%
display(df)
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    4.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5      Carlos    75    1.82
# 6       María    62    1.65
# 7        Juan    85    1.75
# 8       Laura    58    1.63
# 9       Pedro    90    1.78
# 10        Ana    55    1.60
# 11       Luis    78    1.70
# 12      Sofía    60    1.62
# 13     Miguel    82    1.80
# 14      Elena    65    1.67
# 15      Diego    70    1.74
# 16     Carmen    53    1.58
# 17     Javier    88    1.79
# 18     Isabel    59    1.61
# 19    Ricardo    77    1.73

# %%
display(df)
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    4.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5      Carlos    75    1.82
# 6       María    62    1.65
# 7        Juan    85    1.75
# 8       Laura    58    1.63
# 9       Pedro    90    1.78
# 10        Ana    55    1.60
# 11       Luis    78    1.70
# 12      Sofía    60    1.62
# 13     Miguel    82    1.80
# 14      Elena    65    1.67
# 15      Diego    70    1.74
# 16     Carmen    53    1.58
# 17     Javier    88    1.79
# 18     Isabel    59    1.61
# 19    Ricardo    77    1.73
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Peso'].plot(kind='hist', bins=20, title='Peso')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
display(df)
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    4.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5      Carlos    75    1.82
# 6       María    62    1.65
# 7        Juan    85    1.75
# 8       Laura    58    1.63
# 9       Pedro    90    1.78
# 10        Ana    55    1.60
# 11       Luis    78    1.70
# 12      Sofía    60    1.62
# 13     Miguel    82    1.80
# 14      Elena    65    1.67
# 15      Diego    70    1.74
# 16     Carmen    53    1.58
# 17     Javier    88    1.79
# 18     Isabel    59    1.61
# 19    Ricardo    77    1.73

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# * The final DataFrame `df` contains 100 rows and the required columns: 'Nombre', 'Peso', 'Altura', 'IMC', and 'Clasificación IMC'.
# * The 'IMC' values have been calculated for all 100 rows using the formula Peso (kg) / (Altura (m))^2.
# * The 'Clasificación IMC' column accurately categorizes the 'IMC' values for all rows based on the specified ranges: 'Bajo peso' (< 18.5), 'Peso saludable' (18.5 - 24.9), 'Sobrepeso' (25 - 29.9), and 'Obesidad' (>= 30).
#
# ### Insights or Next Steps
#
# * The dataset is ready for further analysis or visualization of the BMI distribution and classification among the individuals.
# * Consider adding age and gender columns to the dataset to allow for more nuanced analysis of BMI trends within different demographic groups.

# %%
display(df)
# Out:
#        Nombre  Peso  Altura        IMC Clasificación IMC
# 0   Alexander    69    1.78  21.777553    Peso saludable
# 1   Alejandra    57    1.60  22.265625    Peso saludable
# 2       Dario    64    4.64   2.972652         Bajo peso
# 3      Wilson    80    1.71  27.358845         Sobrepeso
# 4        Rosa    40    1.53  17.087445         Bajo peso
# ..        ...   ...     ...        ...               ...
# 95    Natalia    77    1.70  26.643599         Sobrepeso
# 96    Gonzalo    77    1.50  34.222222          Obesidad
# 97     Andrea    92    1.71  31.462672          Obesidad
# 98      Lucas    49    1.63  18.442546         Bajo peso
# 99   Carolina    43    1.84  12.700851         Bajo peso
#
# [100 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('Clasificación IMC').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Reasoning**:
# Mostrar el DataFrame completo para verificar que todas las columnas, incluyendo las recién añadidas 'IMC' y 'Clasificación IMC', están presentes y calculadas correctamente para las 100 filas.

# %% [markdown]
# ## Mostrar resultados
#
# ### Subtask:
# Mostrar el DataFrame actualizado con las nuevas columnas 'IMC' y 'Clasificación IMC'.

# %% [markdown]
# # Task
# Modify the DataFrame `df` to include 80 additional rows with Latin American names, resulting in a total of 100 rows. Add two new columns: 'IMC' (Body Mass Index) calculated as Peso (kg) / (Altura (m))^2, and 'Clasificación IMC' based on the following criteria: Less than 18.5: Bajo peso, 18.5 - 24.9: Peso saludable, 25 - 29.9: Sobrepeso, 30 or more: Obesidad.

# %% [markdown]
# ## Generate additional data
#
# ### Subtask:
# Create new lists for 'Nombre', 'Peso', and 'Altura' to reach a total of 100 entries, specifically using Latin American names for the additional rows.

# %% [markdown]
# **Reasoning**:
# Create lists for additional names, weights, and heights to fulfill the subtask requirements.

# %%
import random

additional_nombres = [
    "Sofia", "Santiago", "Valentina", "Mateo", "Isabella", "Sebastian", "Camila", "Nicolas", "Valeria", "Alejandro",
    "Mariana", "Diego", "Gabriela", "Daniel", "Luciana", "Benjamin", "Victoria", "Joaquin", "Martina", "Samuel",
    "Emilia", "David", "Antonella", "Leonardo", "Fatima", "Adrian", "Catalina", "Manuel", "Julieta", "Francisco",
    "Renata", "Thiago", "Agustina", "Juan Pablo", "Mia", "Ignacio", "Elena", "Ricardo", "Isabel", "Fernando",
    "Clara", "Andres", "Paula", "Felipe", "Zoe", "Cristobal", "Violeta", "Esteban", "Abril", "Gabriel",
    "Sara", "Jose", "Emma", "Vicente", "Emilio", "Manuela", "Martin", "Sofia", "Lucia", "Carlos",
    "Maria", "Juan", "Laura", "Pedro", "Ana", "Luis", "Sofía", "Miguel", "Elena", "Diego",
    "Carmen", "Javier", "Isabel", "Ricardo", "Pablo", "Natalia", "Gonzalo", "Andrea", "Lucas", "Carolina"
]

additional_pesos = [random.randint(40, 100) for _ in range(80)]
additional_alturas = [round(random.uniform(1.50, 1.90), 2) for _ in range(80)]

# %% [markdown]
# ## Combine data
#
# ### Subtask:
# Concatenate the existing DataFrame with a new DataFrame created from the generated data to have a single DataFrame with 100 rows.

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame from the additional data and concatenate it with the existing DataFrame. Then reset the index and display the head of the combined DataFrame.

# %%
df_additional = pd.DataFrame({
    "Nombre": additional_nombres,
    "Peso": additional_pesos,
    "Altura": additional_alturas
})

df = pd.concat([df, df_additional], ignore_index=True)
display(df.head())
display(df.tail())
# Out:
#       Nombre  Peso  Altura
# 0  Alexander    69    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    4.64
# 3     Wilson    80    1.71
# 4       Rosa    40    1.53
#       Nombre  Peso  Altura
# 95   Natalia    77    1.70
# 96   Gonzalo    77    1.50
# 97    Andrea    92    1.71
# 98     Lucas    49    1.63
# 99  Carolina    43    1.84

# %% [markdown]
# ## Calculate bmi
#
# ### Subtask:
# Add a new column to the DataFrame called 'IMC' which contains the calculated Body Mass Index (BMI) for each person using the formula: IMC = Peso (kg) / (Altura (m))^2.

# %% [markdown]
# **Reasoning**:
# Calculate the IMC using the Peso and Altura columns and add it as a new column to the dataframe.

# %%
df['IMC'] = df['Peso'] / (df['Altura'] * df['Altura'])
display(df.head())
# Out:
#       Nombre  Peso  Altura        IMC
# 0  Alexander    69    1.78  21.777553
# 1  Alejandra    57    1.60  22.265625
# 2      Dario    64    4.64   2.972652
# 3     Wilson    80    1.71  27.358845
# 4       Rosa    40    1.53  17.087445

# %% [markdown]
# ## Classify bmi
#
# ### Subtask:
# Add another column called 'Clasificación IMC' based on the calculated 'IMC' values according to the provided criteria:
# - Less than 18.5: Underweight
# - 18.5 - 24.9: Healthy weight
# - 25 - 29.9: Overweight
# - 30 or more: Obesity

# %% [markdown]
# **Reasoning**:
# Define a function to classify IMC and apply it to the 'IMC' column to create the 'Clasificación IMC' column, then display the head of the DataFrame.

# %%
def classify_imc(imc):
    if imc < 18.5:
        return 'Underweight'
    elif 18.5 <= imc < 25:
        return 'Healthy weight'
    elif 25 <= imc < 30:
        return 'Overweight'
    else:
        return 'Obesity'

df['Clasificación IMC'] = df['IMC'].apply(classify_imc)
display(df.head())
# Out:
#       Nombre  Peso  Altura        IMC Clasificación IMC
# 0  Alexander    69    1.78  21.777553    Healthy weight
# 1  Alejandra    57    1.60  22.265625    Healthy weight
# 2      Dario    64    4.64   2.972652       Underweight
# 3     Wilson    80    1.71  27.358845        Overweight
# 4       Rosa    40    1.53  17.087445       Underweight

# %% [markdown]
# ## Display results
#
# ### Subtask:
# Display the updated DataFrame with the new 'IMC' and 'Clasificación IMC' columns.

# %% [markdown]
# **Reasoning**:
# Display the entire DataFrame to show all columns including the newly added 'IMC' and 'Clasificación IMC'.

# %%
display(df)
# Out:
#        Nombre  Peso  Altura        IMC Clasificación IMC
# 0   Alexander    69    1.78  21.777553    Healthy weight
# 1   Alejandra    57    1.60  22.265625    Healthy weight
# 2       Dario    64    4.64   2.972652       Underweight
# 3      Wilson    80    1.71  27.358845        Overweight
# 4        Rosa    40    1.53  17.087445       Underweight
# ..        ...   ...     ...        ...               ...
# 95    Natalia    77    1.70  26.643599        Overweight
# 96    Gonzalo    77    1.50  34.222222           Obesity
# 97     Andrea    92    1.71  31.462672           Obesity
# 98      Lucas    49    1.63  18.442546       Underweight
# 99   Carolina    43    1.84  12.700851       Underweight
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The DataFrame was successfully expanded from 20 to 100 rows by adding 80 new entries with Latin American names, random weights between 40kg and 100kg, and random heights between 1.50m and 1.90m.
# *   A new column named 'IMC' was added to the DataFrame, calculating the Body Mass Index for each individual using the formula Peso / (Altura)^2.
# *   A 'Clasificación IMC' column was created, categorizing each individual's BMI into 'Underweight', 'Healthy weight', 'Overweight', or 'Obesity' based on standard BMI ranges.
#
# ### Insights or Next Steps
#
# *   The expanded dataset provides a more robust basis for further analysis of health metrics within a larger population sample.
# *   The combined 'IMC' and 'Clasificación IMC' data can be used for demographic analysis or to identify potential health trends within the dataset.

# %% [markdown]
# # Task
# Generate a pandas DataFrame named `df` with 100 rows and columns 'Nombre', 'Peso', 'Altura', 'IMC', and 'Clasificación IMC'. The 'Nombre' column should contain Latin American names. The 'Peso' and 'Altura' columns should contain numerical data. The 'IMC' column should be calculated as Peso (kg) / (Altura (m))^2. The 'Clasificación IMC' column should categorize the 'IMC' values as follows: 'Bajo peso' (< 18.5), 'Peso saludable' (18.5 - 24.9), 'Sobrepeso' (25 - 29.9), and 'Obesidad' (>= 30). Display the resulting DataFrame.

# %% [markdown]
# ## Generar datos adicionales
#
# ### Subtask:
# Create new lists for 'Nombre', 'Peso', and 'Altura' to reach a total of 100 entries, specifically using Latin American names for the additional rows.

# %% [markdown]
# **Reasoning**:
# Create lists for additional names, weights, and heights to fulfill the subtask requirements.

# %%
import random

additional_nombres = [
    "Sofia", "Santiago", "Valentina", "Mateo", "Isabella", "Sebastian", "Camila", "Nicolas", "Valeria", "Alejandro",
    "Mariana", "Diego", "Gabriela", "Daniel", "Luciana", "Benjamin", "Victoria", "Joaquin", "Martina", "Samuel",
    "Emilia", "David", "Antonella", "Leonardo", "Fatima", "Adrian", "Catalina", "Manuel", "Julieta", "Francisco",
    "Renata", "Thiago", "Agustina", "Juan Pablo", "Mia", "Ignacio", "Elena", "Ricardo", "Isabel", "Fernando",
    "Clara", "Andres", "Paula", "Felipe", "Zoe", "Cristobal", "Violeta", "Esteban", "Abril", "Gabriel",
    "Sara", "Jose", "Emma", "Vicente", "Emilio", "Manuela", "Martin", "Sofia", "Lucia", "Carlos",
    "Maria", "Juan", "Laura", "Pedro", "Ana", "Luis", "Sofía", "Miguel", "Elena", "Diego",
    "Carmen", "Javier", "Isabel", "Ricardo", "Pablo", "Natalia", "Gonzalo", "Andrea", "Lucas", "Carolina"
]

additional_pesos = [random.randint(40, 100) for _ in range(80)]
additional_alturas = [round(random.uniform(1.50, 1.90), 2) for _ in range(80)]

# %% [markdown]
# ## Combinar datos
#
# ### Subtask:
# Concatenate the existing DataFrame with a new DataFrame created from the generated data to have a single DataFrame with 100 rows.

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame from the additional data and concatenate it with the existing DataFrame. Then reset the index and display the head and tail of the combined DataFrame to verify the concatenation.

# %%
df_additional = pd.DataFrame({
    "Nombre": additional_nombres,
    "Peso": additional_pesos,
    "Altura": additional_alturas
})

df = pd.concat([df, df_additional], ignore_index=True)
display(df.head())
display(df.tail())
# Out:
#       Nombre  Peso  Altura        IMC Clasificación IMC
# 0  Alexander    69    1.78  21.777553    Healthy weight
# 1  Alejandra    57    1.60  22.265625    Healthy weight
# 2      Dario    64    4.64   2.972652       Underweight
# 3     Wilson    80    1.71  27.358845        Overweight
# 4       Rosa    40    1.53  17.087445       Underweight
#        Nombre  Peso  Altura  IMC Clasificación IMC
# 175   Natalia    59    1.59  NaN               NaN
# 176   Gonzalo    93    1.57  NaN               NaN
# 177    Andrea    98    1.81  NaN               NaN
# 178     Lucas    98    1.82  NaN               NaN
# 179  Carolina    85    1.85  NaN               NaN

# %% [markdown]
# **Reasoning**:
# The previous step concatenated the dataframes, but the IMC and Clasificación IMC columns for the new rows were not calculated. The next steps are to calculate these columns for the entire dataframe and then display the updated dataframe to verify.

# %%
df = df.head(100).copy()
df['IMC'] = df['Peso'] / (df['Altura'] * df['Altura'])

def classify_imc(imc):
    if imc < 18.5:
        return 'Bajo peso'
    elif 18.5 <= imc < 25:
        return 'Peso saludable'
    elif 25 <= imc < 30:
        return 'Sobrepeso'
    else:
        return 'Obesidad'

df['Clasificación IMC'] = df['IMC'].apply(classify_imc)
display(df.head())
display(df.tail())
# Out:
#       Nombre  Peso  Altura        IMC Clasificación IMC
# 0  Alexander    69    1.78  21.777553    Peso saludable
# 1  Alejandra    57    1.60  22.265625    Peso saludable
# 2      Dario    64    4.64   2.972652         Bajo peso
# 3     Wilson    80    1.71  27.358845         Sobrepeso
# 4       Rosa    40    1.53  17.087445         Bajo peso
#       Nombre  Peso  Altura        IMC Clasificación IMC
# 95   Natalia    77    1.70  26.643599         Sobrepeso
# 96   Gonzalo    77    1.50  34.222222          Obesidad
# 97    Andrea    92    1.71  31.462672          Obesidad
# 98     Lucas    49    1.63  18.442546         Bajo peso
# 99  Carolina    43    1.84  12.700851         Bajo peso

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The final DataFrame `df` contains 100 rows and the required columns: 'Nombre', 'Peso', 'Altura', 'IMC', and 'Clasificación IMC'.
# *   The 'IMC' values have been calculated for all 100 rows using the formula Peso (kg) / (Altura (m))^2.
# *   The 'Clasificación IMC' column accurately categorizes the 'IMC' values for all rows based on the specified ranges: 'Bajo peso' (< 18.5), 'Peso saludable' (18.5 - 24.9), 'Sobrepeso' (25 - 29.9), and 'Obesidad' (>= 30).
#
# ### Insights or Next Steps
#
# *   The dataset is ready for further analysis or visualization of the BMI distribution and classification among the individuals.
# *   Consider adding age and gender columns to the dataset to allow for more nuanced analysis of BMI trends within different demographic groups.
